# %%
# Import the dependencies.

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
import gmaps

from citipy import citipy
from datetime import datetime
from scipy import stats
from scipy.stats import linregress

from config import weather_api_key
from config import g_key

# Get the start time for computation.
start = time.time()

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=80026ba215c9965e6260663fff8da556

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
print(f"There are {len(cities)} cities in the list.")
# Out:
# There are 734 cities in the list.

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lat = "{:.2f}".format(city_lat)
        city_lng = city_weather["coord"]["lon"]
        city_lng = "{:.2f}".format(city_lng)
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yumen
# Processing Record 2 of Set 1 | afmadu
# City not found. Skipping...
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | zaltan
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | okhotsk
# Processing Record 7 of Set 1 | pitimbu
# Processing Record 8 of Set 1 | el real de santa maria
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | ayan
# Processing Record 11 of Set 1 | cabo san lucas
# Processing Record 12 of Set 1 | keetmanshoop
# Processing Record 13 of Set 1 | tasiilaq
# Processing Record 14 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 1 | iberia
# Processing Record 16 of Set 1 | upernavik
# Processing Record 17 of Set 1 | sabang
# Processing Record 18 of Set 1 | pacific grove
# Processing Record 19 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | havre-saint-pierre
# Processing Record 22 of Set 1 | bembereke
# Processing Record 23 of Set 1 | manica
# Processing Record 24 of Set 1 | san patricio
# Processing Record 25 of Set 1 | axim
# Processing Record 26 of Set 1 | mankachar
# Processing Record 27 of Set 1 | thompson
# Processing Record 28 of Set 1 | aasiaat
# Processing Record 29 of Set 1 | luwuk
# Processing Record 30 of Set 1 | beringovskiy
# Processing Record 31 of Set 1 | piacabucu
# Processing Record 32 of Set 1 | kamenka
# Processing Record 33 of Set 1 | uberlandia
# Processing Record 34 of Set 1 | mahibadhoo
# Processing Record 35 of Set 1 | souillac
# Processing Record 36 of Set 1 | oranjemund
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | kutum
# Processing Record 41 of Set 1 | lorengau
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | saint george
# Processing Record 44 of Set 1 | mar del plata
# Processing Record 45 of Set 1 | seoul
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 1 | umri
# Processing Record 49 of Set 1 | sitka
# Processing Record 50 of Set 1 | claresholm
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | sangar
# Processing Record 4 of Set 2 | new norfolk
# Processing Record 5 of Set 2 | saint-philippe
# Processing Record 6 of Set 2 | san cristobal
# Processing Record 7 of Set 2 | severo-kurilsk
# Processing Record 8 of Set 2 | khatanga
# Processing Record 9 of Set 2 | hobyo
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | butaritari
# Processing Record 12 of Set 2 | cayenne
# Processing Record 13 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 2 | lebu
# Processing Record 15 of Set 2 | hilo
# Processing Record 16 of Set 2 | batagay-alyta
# Processing Record 17 of Set 2 | bluff
# Processing Record 18 of Set 2 | leningradskiy
# Processing Record 19 of Set 2 | faanui
# Processing Record 20 of Set 2 | pisco
# Processing Record 21 of Set 2 | murray bridge
# Processing Record 22 of Set 2 | ternate
# Processing Record 23 of Set 2 | port elizabeth
# Processing Record 24 of Set 2 | saskylakh
# Processing Record 25 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 2 | carauari
# Processing Record 27 of Set 2 | ribeira grande
# Processing Record 28 of Set 2 | kolokani
# Processing Record 29 of Set 2 | vila franca do campo
# Processing Record 30 of Set 2 | tuktoyaktuk
# Processing Record 31 of Set 2 | hermanus
# Processing Record 32 of Set 2 | tateyama
# Processing Record 33 of Set 2 | cape town
# Processing Record 34 of Set 2 | punta arenas
# Processing Record 35 of Set 2 | badajoz
# Processing Record 36 of Set 2 | thunder bay
# Processing Record 37 of Set 2 | avarua
# Processing Record 38 of Set 2 | codrington
# Processing Record 39 of Set 2 | hasaki
# Processing Record 40 of Set 2 | dunedin
# Processing Record 41 of Set 2 | mozarlandia
# Processing Record 42 of Set 2 | luderitz
# Processing Record 43 of Set 2 | qaqortoq
# Processing Record 44 of Set 2 | sunrise manor
# Processing Record 45 of Set 2 | vardo
# Processing Record 46 of Set 2 | provideniya
# Processing Record 47 of Set 2 | port-cartier
# Processing Record 48 of Set 2 | puerto escondido
# Processing Record 49 of Set 2 | east london
# Processing Record 50 of Set 2 | gao
# Processing Record 1 of Set 3 | menongue
# Processing Record 2 of Set 3 | kapaa
# Processing Record 3 of Set 3 | flinders
# Processing Record 4 of Set 3 | pangnirtung
# Processing Record 5 of Set 3 | pundaguitan
# Processing Record 6 of Set 3 | naftah
# City not found. Skipping...
# Processing Record 7 of Set 3 | atuona
# Processing Record 8 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 3 | foumban
# Processing Record 11 of Set 3 | sabha
# Processing Record 12 of Set 3 | winnemucca
# Processing Record 13 of Set 3 | adrar
# Processing Record 14 of Set 3 | tiksi
# Processing Record 15 of Set 3 | kaitangata
# Processing Record 16 of Set 3 | sal rei
# Processing Record 17 of Set 3 | walvis bay
# Processing Record 18 of Set 3 | kodiak
# Processing Record 19 of Set 3 | norman wells
# Processing Record 20 of Set 3 | acarau
# Processing Record 21 of Set 3 | beloha
# Processing Record 22 of Set 3 | mayo
# Processing Record 23 of Set 3 | airai
# Processing Record 24 of Set 3 | muroto
# Processing Record 25 of Set 3 | castro
# Processing Record 26 of Set 3 | constitucion
# Processing Record 27 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 3 | victoria
# Processing Record 29 of Set 3 | dingle
# Processing Record 30 of Set 3 | bulungu
# Processing Record 31 of Set 3 | camacha
# Processing Record 32 of Set 3 | port alfred
# Processing Record 33 of Set 3 | albany
# Processing Record 34 of Set 3 | saldanha
# Processing Record 35 of Set 3 | susanville
# Processing Record 36 of Set 3 | acapulco
# Processing Record 37 of Set 3 | nanortalik
# Processing Record 38 of Set 3 | sindou
# Processing Record 39 of Set 3 | esperance
# Processing Record 40 of Set 3 | faya
# Processing Record 41 of Set 3 | bredasdorp
# Processing Record 42 of Set 3 | lasa
# Processing Record 43 of Set 3 | cornelio procopio
# Processing Record 44 of Set 3 | nador
# Processing Record 45 of Set 3 | sukhumi
# Processing Record 46 of Set 3 | fomboni
# Processing Record 47 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 48 of Set 3 | port-gentil
# Processing Record 49 of Set 3 | muravlenko
# Processing Record 50 of Set 3 | sur
# Processing Record 1 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 4 | port hardy
# Processing Record 3 of Set 4 | kemijarvi
# Processing Record 4 of Set 4 | dennery
# Processing Record 5 of Set 4 | ponta do sol
# Processing Record 6 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 4 | altamont
# Processing Record 8 of Set 4 | chuy
# Processing Record 9 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 4 | comodoro rivadavia
# Processing Record 11 of Set 4 | chokurdakh
# Processing Record 12 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 4 | ancud
# Processing Record 14 of Set 4 | kem
# Processing Record 15 of Set 4 | golden
# Processing Record 16 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 4 | bonfim
# Processing Record 18 of Set 4 | osorio
# Processing Record 19 of Set 4 | tomatlan
# Processing Record 20 of Set 4 | anadyr
# Processing Record 21 of Set 4 | iqaluit
# Processing Record 22 of Set 4 | qasigiannguit
# Processing Record 23 of Set 4 | richards bay
# Processing Record 24 of Set 4 | sao filipe
# Processing Record 25 of Set 4 | taoudenni
# Processing Record 26 of Set 4 | dali
# Processing Record 27 of Set 4 | neosho
# Processing Record 28 of Set 4 | salinas
# Processing Record 29 of Set 4 | vaitape
# Processing Record 30 of Set 4 | alofi
# Processing Record 31 of Set 4 | elizabeth city
# Processing Record 32 of Set 4 | orikum
# Processing Record 33 of Set 4 | caravelas
# Processing Record 34 of Set 4 | kerman
# Processing Record 35 of Set 4 | kavieng
# Processing Record 36 of Set 4 | griffith
# Processing Record 37 of Set 4 | kalmunai
# Processing Record 38 of Set 4 | vyazemskiy
# Processing Record 39 of Set 4 | kupang
# Processing Record 40 of Set 4 | noumea
# Processing Record 41 of Set 4 | copiapo
# Processing Record 42 of Set 4 | mincivan
# Processing Record 43 of Set 4 | sayyan
# Processing Record 44 of Set 4 | palmer
# Processing Record 45 of Set 4 | mlawa
# Processing Record 46 of Set 4 | fortuna
# Processing Record 47 of Set 4 | torbay
# Processing Record 48 of Set 4 | solnechnyy
# Processing Record 49 of Set 4 | hoquiam
# Processing Record 50 of Set 4 | salym
# Processing Record 1 of Set 5 | smithers
# Processing Record 2 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 5 | taseyevo
# Processing Record 4 of Set 5 | ahipara
# Processing Record 5 of Set 5 | neiafu
# Processing Record 6 of Set 5 | yurimaguas
# Processing Record 7 of Set 5 | solok
# Processing Record 8 of Set 5 | tabialan
# City not found. Skipping...
# Processing Record 9 of Set 5 | narasannapeta
# Processing Record 10 of Set 5 | sukheke
# City not found. Skipping...
# Processing Record 11 of Set 5 | quatre cocos
# Processing Record 12 of Set 5 | sulangan
# Processing Record 13 of Set 5 | yulara
# Processing Record 14 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 15 of Set 5 | lufilufi
# Processing Record 16 of Set 5 | salalah
# Processing Record 17 of Set 5 | mikhaylovka
# Processing Record 18 of Set 5 | talnakh
# Processing Record 19 of Set 5 | georgetown
# Processing Record 20 of Set 5 | marquard
# Processing Record 21 of Set 5 | lardos
# Processing Record 22 of Set 5 | hirara
# Processing Record 23 of Set 5 | san ramon de la nueva oran
# Processing Record 24 of Set 5 | puerto barrios
# Processing Record 25 of Set 5 | katsuura
# Processing Record 26 of Set 5 | arlit
# Processing Record 27 of Set 5 | port lincoln
# Processing Record 28 of Set 5 | sinjar
# Processing Record 29 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 5 | cap malheureux
# Processing Record 31 of Set 5 | clyde river
# Processing Record 32 of Set 5 | xining
# Processing Record 33 of Set 5 | awjilah
# Processing Record 34 of Set 5 | nikolskoye
# Processing Record 35 of Set 5 | sidi ali
# Processing Record 36 of Set 5 | visnes
# Processing Record 37 of Set 5 | tefe
# Processing Record 38 of Set 5 | antofagasta
# Processing Record 39 of Set 5 | iracoubo
# Processing Record 40 of Set 5 | altagracia de orituco
# Processing Record 41 of Set 5 | isangel
# Processing Record 42 of Set 5 | carnarvon
# Processing Record 43 of Set 5 | orlik
# Processing Record 44 of Set 5 | kerki
# City not found. Skipping...
# Processing Record 45 of Set 5 | weligama
# Processing Record 46 of Set 5 | lompoc
# Processing Record 47 of Set 5 | potosi
# Processing Record 48 of Set 5 | vreed en hoop
# City not found. Skipping...
# Processing Record 49 of Set 5 | bambous virieux
# Processing Record 50 of Set 5 | kargasok
# Processing Record 1 of Set 6 | asyut
# Processing Record 2 of Set 6 | tilichiki
# Processing Record 3 of Set 6 | mpika
# Processing Record 4 of Set 6 | hithadhoo
# Processing Record 5 of Set 6 | morant bay
# Processing Record 6 of Set 6 | saraland
# Processing Record 7 of Set 6 | sao jose da coroa grande
# Processing Record 8 of Set 6 | canmore
# Processing Record 9 of Set 6 | vostok
# Processing Record 10 of Set 6 | cuiluan
# Processing Record 11 of Set 6 | charters towers
# Processing Record 12 of Set 6 | laives
# Processing Record 13 of Set 6 | sibu
# Processing Record 14 of Set 6 | kasane
# Processing Record 15 of Set 6 | talcahuano
# Processing Record 16 of Set 6 | bambanglipuro
# Processing Record 17 of Set 6 | sanming
# Processing Record 18 of Set 6 | portland
# Processing Record 19 of Set 6 | san quintin
# Processing Record 20 of Set 6 | jalu
# Processing Record 21 of Set 6 | caucaia
# Processing Record 22 of Set 6 | giulianova
# Processing Record 23 of Set 6 | farafangana
# Processing Record 24 of Set 6 | northfield
# Processing Record 25 of Set 6 | moyale
# Processing Record 26 of Set 6 | cairns
# Processing Record 27 of Set 6 | saint-joseph
# Processing Record 28 of Set 6 | kaka
# Processing Record 29 of Set 6 | olafsvik
# Processing Record 30 of Set 6 | coihueco
# Processing Record 31 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 6 | mahebourg
# Processing Record 33 of Set 6 | nouadhibou
# Processing Record 34 of Set 6 | bazaliya
# Processing Record 35 of Set 6 | waipawa
# Processing Record 36 of Set 6 | shimoda
# Processing Record 37 of Set 6 | matamoros
# Processing Record 38 of Set 6 | belomorsk
# Processing Record 39 of Set 6 | kurumkan
# Processing Record 40 of Set 6 | arraial do cabo
# Processing Record 41 of Set 6 | puri
# Processing Record 42 of Set 6 | lastoursville
# Processing Record 43 of Set 6 | nyimba
# Processing Record 44 of Set 6 | hervey bay
# Processing Record 45 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 6 | anqing
# Processing Record 47 of Set 6 | cabras
# Processing Record 48 of Set 6 | alta floresta
# Processing Record 49 of Set 6 | qui nhon
# Processing Record 50 of Set 6 | itapipoca
# Processing Record 1 of Set 7 | eyl
# Processing Record 2 of Set 7 | nhulunbuy
# Processing Record 3 of Set 7 | bethel
# Processing Record 4 of Set 7 | bekhtery
# Processing Record 5 of Set 7 | namibe
# Processing Record 6 of Set 7 | vao
# Processing Record 7 of Set 7 | abha
# Processing Record 8 of Set 7 | panguna
# Processing Record 9 of Set 7 | maniitsoq
# Processing Record 10 of Set 7 | mayachnyy
# Processing Record 11 of Set 7 | dubuque
# Processing Record 12 of Set 7 | tuatapere
# Processing Record 13 of Set 7 | hamilton
# Processing Record 14 of Set 7 | sakaiminato
# Processing Record 15 of Set 7 | viesca
# Processing Record 16 of Set 7 | burns lake
# Processing Record 17 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 18 of Set 7 | tselinnoye
# Processing Record 19 of Set 7 | bay roberts
# Processing Record 20 of Set 7 | malatya
# Processing Record 21 of Set 7 | samarai
# Processing Record 22 of Set 7 | narsaq
# Processing Record 23 of Set 7 | manzhouli
# Processing Record 24 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 7 | ewo
# Processing Record 26 of Set 7 | paucartambo
# City not found. Skipping...
# Processing Record 27 of Set 7 | belaya gora
# Processing Record 28 of Set 7 | atar
# Processing Record 29 of Set 7 | chapais
# Processing Record 30 of Set 7 | yar-sale
# Processing Record 31 of Set 7 | goure
# Processing Record 32 of Set 7 | hualmay
# Processing Record 33 of Set 7 | isla vista
# Processing Record 34 of Set 7 | nelson bay
# Processing Record 35 of Set 7 | mondovi
# Processing Record 36 of Set 7 | port hedland
# Processing Record 37 of Set 7 | raga
# Processing Record 38 of Set 7 | mazatlan
# Processing Record 39 of Set 7 | lomianki
# Processing Record 40 of Set 7 | clovis
# Processing Record 41 of Set 7 | paamiut
# Processing Record 42 of Set 7 | ca mau
# Processing Record 43 of Set 7 | sakakah
# Processing Record 44 of Set 7 | seymchan
# Processing Record 45 of Set 7 | nalut
# Processing Record 46 of Set 7 | castlemaine
# Processing Record 47 of Set 7 | istok
# Processing Record 48 of Set 7 | erenhot
# Processing Record 49 of Set 7 | lagoa
# Processing Record 50 of Set 7 | dumas
# Processing Record 1 of Set 8 | punta alta
# Processing Record 2 of Set 8 | mogadishu
# Processing Record 3 of Set 8 | okmulgee
# Processing Record 4 of Set 8 | mixtequilla
# City not found. Skipping...
# Processing Record 5 of Set 8 | dakar
# Processing Record 6 of Set 8 | coihaique
# Processing Record 7 of Set 8 | vinh
# Processing Record 8 of Set 8 | marilandia
# Processing Record 9 of Set 8 | portobelo
# Processing Record 10 of Set 8 | lerwick
# Processing Record 11 of Set 8 | otradnoye
# Processing Record 12 of Set 8 | arman
# Processing Record 13 of Set 8 | tarbagatay
# Processing Record 14 of Set 8 | vanavara
# Processing Record 15 of Set 8 | svecha
# Processing Record 16 of Set 8 | burica
# City not found. Skipping...
# Processing Record 17 of Set 8 | lososina
# Processing Record 18 of Set 8 | jieshi
# Processing Record 19 of Set 8 | bathsheba
# Processing Record 20 of Set 8 | lagunas
# Processing Record 21 of Set 8 | lokoja
# Processing Record 22 of Set 8 | egvekinot
# Processing Record 23 of Set 8 | borujerd
# Processing Record 24 of Set 8 | guerrero negro
# Processing Record 25 of Set 8 | jepara
# Processing Record 26 of Set 8 | klaksvik
# Processing Record 27 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 8 | tura
# Processing Record 29 of Set 8 | cockburn town
# Processing Record 30 of Set 8 | sanchor
# Processing Record 31 of Set 8 | vazhiny
# Processing Record 32 of Set 8 | kruisfontein
# Processing Record 33 of Set 8 | sola
# Processing Record 34 of Set 8 | korla
# Processing Record 35 of Set 8 | trinidad
# Processing Record 36 of Set 8 | lubango
# Processing Record 37 of Set 8 | sampit
# Processing Record 38 of Set 8 | mumbwa
# Processing Record 39 of Set 8 | timbo
# Processing Record 40 of Set 8 | meadow lake
# Processing Record 41 of Set 8 | rozmital pod tremsinem
# Processing Record 42 of Set 8 | america dourada
# Processing Record 43 of Set 8 | grand gaube
# Processing Record 44 of Set 8 | samborondon
# Processing Record 45 of Set 8 | luwingu
# Processing Record 46 of Set 8 | douglas
# Processing Record 47 of Set 8 | ha giang
# Processing Record 48 of Set 8 | ust-kan
# Processing Record 49 of Set 8 | capim grosso
# Processing Record 50 of Set 8 | orange
# Processing Record 1 of Set 9 | faruka
# Processing Record 2 of Set 9 | deputatskiy
# Processing Record 3 of Set 9 | bintulu
# Processing Record 4 of Set 9 | las vegas
# Processing Record 5 of Set 9 | pangody
# Processing Record 6 of Set 9 | zhizdra
# Processing Record 7 of Set 9 | margate
# Processing Record 8 of Set 9 | augusto correa
# Processing Record 9 of Set 9 | kapoeta
# Processing Record 10 of Set 9 | catuday
# Processing Record 11 of Set 9 | cherskiy
# Processing Record 12 of Set 9 | taruma
# Processing Record 13 of Set 9 | mchinji
# Processing Record 14 of Set 9 | dikson
# Processing Record 15 of Set 9 | nome
# Processing Record 16 of Set 9 | rio gallegos
# Processing Record 17 of Set 9 | casa nova
# Processing Record 18 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 9 | phan thiet
# Processing Record 20 of Set 9 | jinchengjiang
# City not found. Skipping...
# Processing Record 21 of Set 9 | grindavik
# Processing Record 22 of Set 9 | ulladulla
# Processing Record 23 of Set 9 | srednekolymsk
# Processing Record 24 of Set 9 | mahajanga
# Processing Record 25 of Set 9 | longyearbyen
# Processing Record 26 of Set 9 | verkhoyansk
# Processing Record 27 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 28 of Set 9 | tabou
# Processing Record 29 of Set 9 | santa isabel
# Processing Record 30 of Set 9 | chickasha
# Processing Record 31 of Set 9 | katsiveli
# City not found. Skipping...
# Processing Record 32 of Set 9 | taltal
# Processing Record 33 of Set 9 | bengkulu
# Processing Record 34 of Set 9 | najran
# Processing Record 35 of Set 9 | ulaanbaatar
# Processing Record 36 of Set 9 | beaverlodge
# Processing Record 37 of Set 9 | kailua
# Processing Record 38 of Set 9 | north bend
# Processing Record 39 of Set 9 | jumla
# Processing Record 40 of Set 9 | roma
# Processing Record 41 of Set 9 | ust-omchug
# Processing Record 42 of Set 9 | bairiki
# Processing Record 43 of Set 9 | andra
# Processing Record 44 of Set 9 | port hawkesbury
# Processing Record 45 of Set 9 | pondicherry
# Processing Record 46 of Set 9 | honningsvag
# Processing Record 47 of Set 9 | thanh hoa
# Processing Record 48 of Set 9 | halifax
# Processing Record 49 of Set 9 | katherine
# Processing Record 50 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 10 | verkhnyaya sinyachikha
# Processing Record 2 of Set 10 | san francisco
# Processing Record 3 of Set 10 | bayan
# Processing Record 4 of Set 10 | eureka
# Processing Record 5 of Set 10 | apt
# Processing Record 6 of Set 10 | williamsburg
# Processing Record 7 of Set 10 | buchanan
# Processing Record 8 of Set 10 | maceio
# Processing Record 9 of Set 10 | bulawayo
# Processing Record 10 of Set 10 | coahuayana
# Processing Record 11 of Set 10 | aripuana
# Processing Record 12 of Set 10 | vestmannaeyjar
# Processing Record 13 of Set 10 | honiara
# Processing Record 14 of Set 10 | kerrville
# Processing Record 15 of Set 10 | barcelos
# Processing Record 16 of Set 10 | benghazi
# Processing Record 17 of Set 10 | kavaratti
# Processing Record 18 of Set 10 | along
# Processing Record 19 of Set 10 | morondava
# Processing Record 20 of Set 10 | calabozo
# Processing Record 21 of Set 10 | langham
# Processing Record 22 of Set 10 | muisne
# Processing Record 23 of Set 10 | dongsheng
# Processing Record 24 of Set 10 | kontagora
# Processing Record 25 of Set 10 | altamira
# Processing Record 26 of Set 10 | broken hill
# Processing Record 27 of Set 10 | roald
# Processing Record 28 of Set 10 | oranjestad
# Processing Record 29 of Set 10 | udachnyy
# Processing Record 30 of Set 10 | bayshore gardens
# Processing Record 31 of Set 10 | pevek
# Processing Record 32 of Set 10 | cattolica
# Processing Record 33 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 34 of Set 10 | cidreira
# Processing Record 35 of Set 10 | batemans bay
# Processing Record 36 of Set 10 | kudahuvadhoo
# Processing Record 37 of Set 10 | ondjiva
# Processing Record 38 of Set 10 | bataipora
# Processing Record 39 of Set 10 | pran buri
# Processing Record 40 of Set 10 | sokoni
# Processing Record 41 of Set 10 | haines junction
# Processing Record 42 of Set 10 | zhigansk
# Processing Record 43 of Set 10 | strezhevoy
# Processing Record 44 of Set 10 | maua
# Processing Record 45 of Set 10 | derzhavinsk
# Processing Record 46 of Set 10 | sirjan
# Processing Record 47 of Set 10 | bhadasar
# Processing Record 48 of Set 10 | longyan
# Processing Record 49 of Set 10 | natitingou
# Processing Record 50 of Set 10 | moose factory
# Processing Record 1 of Set 11 | college
# Processing Record 2 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 3 of Set 11 | la asuncion
# Processing Record 4 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 11 | murgab
# Processing Record 6 of Set 11 | songadh
# Processing Record 7 of Set 11 | mangai
# Processing Record 8 of Set 11 | izazi
# Processing Record 9 of Set 11 | toftir
# City not found. Skipping...
# Processing Record 10 of Set 11 | tocopilla
# Processing Record 11 of Set 11 | westport
# Processing Record 12 of Set 11 | la ronge
# Processing Record 13 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 14 of Set 11 | san luis
# Processing Record 15 of Set 11 | havoysund
# Processing Record 16 of Set 11 | contai
# Processing Record 17 of Set 11 | nipawin
# Processing Record 18 of Set 11 | puerto morazan
# Processing Record 19 of Set 11 | lakes entrance
# Processing Record 20 of Set 11 | te anau
# Processing Record 21 of Set 11 | kampene
# Processing Record 22 of Set 11 | qingquan
# Processing Record 23 of Set 11 | le tampon
# Processing Record 24 of Set 11 | chegdomyn
# Processing Record 25 of Set 11 | shenjiamen
# Processing Record 26 of Set 11 | aykhal
# Processing Record 27 of Set 11 | tigil
# Processing Record 28 of Set 11 | letka
# Processing Record 29 of Set 11 | cariamanga
# Processing Record 30 of Set 11 | grand-lahou
# Processing Record 31 of Set 11 | severodvinsk
# Processing Record 32 of Set 11 | labuan
# Processing Record 33 of Set 11 | prince rupert
# Processing Record 34 of Set 11 | saint anthony
# Processing Record 35 of Set 11 | orapa
# Processing Record 36 of Set 11 | dukat
# Processing Record 37 of Set 11 | tupelo
# Processing Record 38 of Set 11 | rosita
# Processing Record 39 of Set 11 | hovd
# Processing Record 40 of Set 11 | barabinsk
# Processing Record 41 of Set 11 | tiznit
# Processing Record 42 of Set 11 | mecca
# Processing Record 43 of Set 11 | guilin
# Processing Record 44 of Set 11 | tshikapa
# Processing Record 45 of Set 11 | komsomolskiy
# Processing Record 46 of Set 11 | vanimo
# Processing Record 47 of Set 11 | lokosovo
# Processing Record 48 of Set 11 | changji
# Processing Record 49 of Set 11 | oyama
# Processing Record 50 of Set 11 | inongo
# Processing Record 1 of Set 12 | alyangula
# Processing Record 2 of Set 12 | urumqi
# Processing Record 3 of Set 12 | iskateley
# Processing Record 4 of Set 12 | ust-ilimsk
# Processing Record 5 of Set 12 | dzheyrakh
# Processing Record 6 of Set 12 | chimbote
# Processing Record 7 of Set 12 | jacareacanga
# Processing Record 8 of Set 12 | berlevag
# Processing Record 9 of Set 12 | ballina
# Processing Record 10 of Set 12 | ust-nera
# Processing Record 11 of Set 12 | magaria
# Processing Record 12 of Set 12 | los llanos de aridane
# Processing Record 13 of Set 12 | japura
# Processing Record 14 of Set 12 | fairbanks
# Processing Record 15 of Set 12 | alice springs
# Processing Record 16 of Set 12 | sembe
# Processing Record 17 of Set 12 | half moon bay
# Processing Record 18 of Set 12 | talaya
# Processing Record 19 of Set 12 | salinopolis
# Processing Record 20 of Set 12 | saint-pierre
# Processing Record 21 of Set 12 | jardim
# Processing Record 22 of Set 12 | makakilo city
# Processing Record 23 of Set 12 | butembo
# Processing Record 24 of Set 12 | agaro
# Processing Record 25 of Set 12 | zyryanka
# Processing Record 26 of Set 12 | aginskoye
# Processing Record 27 of Set 12 | kalamare
# Processing Record 28 of Set 12 | itaueira
# Processing Record 29 of Set 12 | havelock
# Processing Record 30 of Set 12 | puerto penasco
# Processing Record 31 of Set 12 | bon accord
# Processing Record 32 of Set 12 | fare
# Processing Record 33 of Set 12 | belyy yar
# Processing Record 34 of Set 12 | kandalaksha
# Processing Record 35 of Set 12 | hay river
# Processing Record 36 of Set 12 | iwaki
# Processing Record 37 of Set 12 | kjollefjord
# Processing Record 38 of Set 12 | mareeba
# Processing Record 39 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 12 | saint-georges
# Processing Record 41 of Set 12 | brewster
# Processing Record 42 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 12 | ambilobe
# Processing Record 44 of Set 12 | moa
# Processing Record 45 of Set 12 | bloomfield
# Processing Record 46 of Set 12 | oil city
# Processing Record 47 of Set 12 | itarema
# Processing Record 48 of Set 12 | gazli
# Processing Record 49 of Set 12 | mayor pablo lagerenza
# Processing Record 50 of Set 12 | geraldton
# Processing Record 1 of Set 13 | canaries
# Processing Record 2 of Set 13 | presidente medici
# Processing Record 3 of Set 13 | khotyn
# Processing Record 4 of Set 13 | ibra
# Processing Record 5 of Set 13 | zaysan
# Processing Record 6 of Set 13 | lata
# Processing Record 7 of Set 13 | assiniboia
# Processing Record 8 of Set 13 | banposh
# Processing Record 9 of Set 13 | yomitan
# City not found. Skipping...
# Processing Record 10 of Set 13 | ostrovnoy
# Processing Record 11 of Set 13 | bela
# Processing Record 12 of Set 13 | sainte-thecle
# Processing Record 13 of Set 13 | usvyaty
# Processing Record 14 of Set 13 | luau
# Processing Record 15 of Set 13 | inirida
# Processing Record 16 of Set 13 | elko
# Processing Record 17 of Set 13 | tivaouane
# Processing Record 18 of Set 13 | saint-francois
# Processing Record 19 of Set 13 | atherton
# Processing Record 20 of Set 13 | russell
# Processing Record 21 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 22 of Set 13 | zlobin
# Processing Record 23 of Set 13 | sijunjung
# Processing Record 24 of Set 13 | novikovo
# Processing Record 25 of Set 13 | tarazona
# Processing Record 26 of Set 13 | erzin
# Processing Record 27 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 13 | rapallo
# Processing Record 29 of Set 13 | buraydah
# Processing Record 30 of Set 13 | meulaboh
# Processing Record 31 of Set 13 | abbeville
# Processing Record 32 of Set 13 | omsukchan
# Processing Record 33 of Set 13 | bend
# Processing Record 34 of Set 13 | lavrentiya
# Processing Record 35 of Set 13 | manhattan
# Processing Record 36 of Set 13 | almeirim
# Processing Record 37 of Set 13 | kavali
# Processing Record 38 of Set 13 | san clemente
# Processing Record 39 of Set 13 | mount isa
# Processing Record 40 of Set 13 | bridlington
# Processing Record 41 of Set 13 | puteyets
# Processing Record 42 of Set 13 | port augusta
# Processing Record 43 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 44 of Set 13 | dengfeng
# Processing Record 45 of Set 13 | nishihara
# Processing Record 46 of Set 13 | ndjole
# Processing Record 47 of Set 13 | boueni
# Processing Record 48 of Set 13 | katima mulilo
# Processing Record 49 of Set 13 | khandyga
# Processing Record 50 of Set 13 | warmbad
# Processing Record 1 of Set 14 | peniche
# Processing Record 2 of Set 14 | dauphin
# Processing Record 3 of Set 14 | mugur-aksy
# Processing Record 4 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 5 of Set 14 | biltine
# Processing Record 6 of Set 14 | salamanca
# Processing Record 7 of Set 14 | mwinilunga
# Processing Record 8 of Set 14 | gharghoda
# Processing Record 9 of Set 14 | port blair
# Processing Record 10 of Set 14 | seminole
# Processing Record 11 of Set 14 | mbeya
# Processing Record 12 of Set 14 | mahanoro
# Processing Record 13 of Set 14 | darhan
# Processing Record 14 of Set 14 | veraval
# Processing Record 15 of Set 14 | borgarnes
# Processing Record 16 of Set 14 | zhanakorgan
# Processing Record 17 of Set 14 | tapes
# Processing Record 18 of Set 14 | soe
# Processing Record 19 of Set 14 | flin flon
# Processing Record 20 of Set 14 | doctor juan leon mallorquin
# Processing Record 21 of Set 14 | latung
# Processing Record 22 of Set 14 | avera
# Processing Record 23 of Set 14 | yerbogachen
# Processing Record 24 of Set 14 | aklavik
# Processing Record 25 of Set 14 | las palmas
# Processing Record 26 of Set 14 | talara
# Processing Record 27 of Set 14 | jiayuguan
# Processing Record 28 of Set 14 | gaogou
# Processing Record 29 of Set 14 | cullman
# Processing Record 30 of Set 14 | vetluzhskiy
# Processing Record 31 of Set 14 | mayen
# Processing Record 32 of Set 14 | teo
# Processing Record 33 of Set 14 | florida
# Processing Record 34 of Set 14 | santa catalina
# Processing Record 35 of Set 14 | gorzow wielkopolski
# Processing Record 36 of Set 14 | porto novo
# Processing Record 37 of Set 14 | bousse
# Processing Record 38 of Set 14 | garm
# City not found. Skipping...
# Processing Record 39 of Set 14 | machacamarca
# Processing Record 40 of Set 14 | poum
# Processing Record 41 of Set 14 | akyab
# Processing Record 42 of Set 14 | basco
# Processing Record 43 of Set 14 | sambava
# Processing Record 44 of Set 14 | laguna
# Processing Record 45 of Set 14 | nabire
# Processing Record 46 of Set 14 | nizhniy baskunchak
# Processing Record 47 of Set 14 | pokosnoye
# Processing Record 48 of Set 14 | olga
# Processing Record 49 of Set 14 | monclova
# Processing Record 50 of Set 14 | tashtagol
# Processing Record 1 of Set 15 | hambantota
# Processing Record 2 of Set 15 | byron bay
# Processing Record 3 of Set 15 | olinda
# Processing Record 4 of Set 15 | kawalu
# Processing Record 5 of Set 15 | ambovombe
# Processing Record 6 of Set 15 | baghdad
# Processing Record 7 of Set 15 | bubaque
# Processing Record 8 of Set 15 | bridgewater
# Processing Record 9 of Set 15 | yeppoon
# Processing Record 10 of Set 15 | celestun
# Processing Record 11 of Set 15 | ashington
# Processing Record 12 of Set 15 | hokitika
# Processing Record 13 of Set 15 | edremit
# Processing Record 14 of Set 15 | multai
# Processing Record 15 of Set 15 | pokhara
# Processing Record 16 of Set 15 | ilulissat
# Processing Record 17 of Set 15 | ruvo di puglia
# Processing Record 18 of Set 15 | kaniama
# Processing Record 19 of Set 15 | kuminskiy
# Processing Record 20 of Set 15 | pachino
# Processing Record 21 of Set 15 | antsohihy
# Processing Record 22 of Set 15 | muros
# Processing Record 23 of Set 15 | campo grande
# Processing Record 24 of Set 15 | pervomayskoye
# Processing Record 25 of Set 15 | zhezkazgan
# Processing Record 26 of Set 15 | stalis
# Processing Record 27 of Set 15 | podgornoye
# Processing Record 28 of Set 15 | kulhudhuffushi
# Processing Record 29 of Set 15 | astorga
# Processing Record 30 of Set 15 | ati
# Processing Record 31 of Set 15 | ust-karsk
# Processing Record 32 of Set 15 | alekseyevka
# Processing Record 33 of Set 15 | tuy hoa
# Processing Record 34 of Set 15 | mayumba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# Display the output to verify.
city_data_df
# Out:
#             City Country     Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0          Yumen      CN   40.28    97.20     62.67         9           0
# 1          Vaini      TO  -21.20  -175.20     73.56       100          20
# 2         Zaltan      LY   32.95    11.87     69.10        40           0
# 3      Busselton      AU  -33.65   115.33     59.97        79          99
# 4        Okhotsk      RU   59.38   143.30     20.73        91         100
# ..           ...     ...     ...      ...       ...       ...         ...
# 679          Ati      TD   13.22    18.34    108.61         6           5
# 680    Ust-Karsk      RU   52.70   118.81     33.15        78          74
# 681  Alekseyevka      RU   50.63    38.69     57.90        53          96
# 682      Tuy Hoa      VN   13.08   109.30     73.18        85          65
# 683      Mayumba      GA   -3.43    10.66     81.34        80          44
#
#      Wind Speed Current Description
# 0         11.59           clear sky
# 1          3.44          few clouds
# 2         15.48           clear sky
# 3         12.39     overcast clouds
# 4          6.40     overcast clouds
# ..          ...                 ...
# 679        7.47           clear sky
# 680        2.28       broken clouds
# 681       12.01     overcast clouds
# 682        9.86       broken clouds
# 683        8.68          light rain
#
# [684 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Display total computational time.
end = time.time()
total_time = end - start
seconds = total_time % 3600
minutes = seconds // 60
seconds %= 60
print(f"Total time elapsed = {minutes:.0f} minutes {seconds:.0f} seconds")
# Out:
# Total time elapsed = 3 minutes 10 seconds
